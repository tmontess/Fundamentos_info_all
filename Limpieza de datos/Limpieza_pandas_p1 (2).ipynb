# %%
import pandas as pd

# %%
cines = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRSa9oM9fC-QlT7VOeGhZQtrWnlNSTsk3U8DWGTOXUWtPH6u9o5O5eZ0kTg8mFTwAn9vMdGRK7o2SPB/pub?gid=969960562&single=true&output=csv")
cines.head(3)
# Out:
#    loc_code  prov_id  dep_id  obs       category   province    department  \
# 0  10049030       10   10049  NaN  Salas de cine  Catamarca       Capital
# 1  10091150       10   10091  NaN  Salas de cine  Catamarca   Santa Maria
# 2  22140060       22   22140  NaN  Salas de cine      Chaco  San Fernando
#
#           city                         name                        address  \
# 0    Catamarca                 Cinemacenter  Intendente Mamerto Medina 220
# 1  Santa María  Centro Cultural San Agustín                 San Martin 173
# 2  Resistencia        Los Cines De La Costa             Av. Sarmiento 2600
#
#   floor  zip_code area_code             sector  screens  seats  update_year
# 0   s/d      4700       s/d  Privado comercial        5    743         2018
# 1   s/d      4139      3838  Privado comercial        1    440         2018
# 2   s/d      3500      3794  Privado comercial        5    820         2018

# %%
cines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   loc_code     329 non-null    int64
#  1   prov_id      329 non-null    int64
#  2   dep_id       329 non-null    int64
#  3   obs          0 non-null      float64
#  4   category     329 non-null    object
#  5   province     329 non-null    object
#  6   department   329 non-null    object
#  7   city         329 non-null    object
#  8   name         329 non-null    object
#  9   address      329 non-null    object
#  10  floor        329 non-null    object
#  11  zip_code     329 non-null    int64
#  12  area_code    329 non-null    object
#  13  sector       329 non-null    object
#  14  screens      329 non-null    int64
#  15  seats        329 non-null    int64
#  16  update_year  329 non-null    int64
# dtypes: float64(1), int64(7), object(9)
# memory usage: 43.8+ KB

# %%
cines.describe()
# Out:
#            loc_code    prov_id        dep_id  obs     zip_code     screens  \
# count  3.290000e+02  329.00000    329.000000  0.0   329.000000  329.000000
# mean   2.974710e+07   29.56231  29746.987842  NaN  4461.072948    2.960486
# std    2.935827e+07   29.46189  29358.276444  NaN  2427.054423    3.078489
# min    2.000010e+06    2.00000   2000.000000  NaN  1001.000000    1.000000
# 25%    6.441030e+06    6.00000   6441.000000  NaN  2000.000000    1.000000
# 50%    1.404217e+07   14.00000  14042.000000  NaN  4400.000000    1.000000
# 75%    5.010521e+07   50.00000  50105.000000  NaN  6305.000000    4.000000
# max    9.401402e+07   94.00000  94014.000000  NaN  9420.000000   17.000000
#
#              seats  update_year
# count   329.000000        329.0
# mean    701.042553       2018.0
# std     709.452257          0.0
# min       0.000000       2018.0
# 25%     245.000000       2018.0
# 50%     420.000000       2018.0
# 75%     907.000000       2018.0
# ...

# %%
cines.isnull().sum() #cuantos datos faltantes
# Out:
# loc_code         0
# prov_id          0
# dep_id           0
# obs            329
# category         0
# province         0
# department       0
# city             0
# name             0
# address          0
# floor            0
# zip_code         0
# area_code        0
# sector           0
# screens          0
# seats            0
# update_year      0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(cines.isnull(), cmap='viridis') #datos faltantes de forma gráfica
# Out:
# <AxesSubplot:>

# %%
#eliminar toda las filas que contienen un dato faltante:
"cines.dropna(inplace=True)"
# Out:
# 'cines.dropna(inplace=True)'

# %%
#aquellas que tienen más de un dato faltante:
"cines.dropna(thresh=2, inplace=True)"
# Out:
# 'cines.dropna(thresh=2, inplace=True)'

# %%
#eliminación por columna
cines.drop(['obs'], axis=1, inplace=True)

# %%
#última alternativa reemplazando los valores faltantes por la MEDIA
"df.fillna(df['obd'].mean(), inplace=True)"
# Out:
# "df.fillna(df['obd'].mean(), inplace=True)"

# %%
sns.heatmap(cines.isnull(), cmap='viridis') #impecable
# Out:
# <AxesSubplot:>

# %%
cines['loc_code'].dtypes # conocer el tipo de dato al que se corresponde una columna
# Out:
# dtype('int64')

# %%
cines['loc_code'] = pd.to_numeric(cines['loc_code'], errors='coerce') 
#convertir una columna a tipo de dato numérico,

# %%
cines.drop_duplicates(inplace=True) #remover celdas duplicadas
