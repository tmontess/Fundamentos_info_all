# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

iris = pd.read_csv('iris_data.txt', sep= '\t')

# %%
import seaborn as sns

g = sns.histplot(data = iris, x = "sepal.length", binwidth=0.25, kde = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 4
#       1 import seaborn as sns
#       3 g = sns.histplot(data = iris, x = "sepal.length", binwidth=0.25, kde = True)
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import seaborn as sns

g = sns.pairplot(iris)

#aca se puede ver que no solo tomo un tipo de plantas si no que tomo distintos tipos de plantas
# tomo varias de un tipo y de otras la separacion de los puntos se pueden ver las dos poblaicones 
# difernetes de datos
